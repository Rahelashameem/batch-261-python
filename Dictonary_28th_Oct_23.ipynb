# %%
## Dictionaries

-     Dictionary in Python is a collection of keys values, used to store data values like a map, which, unlike other data types       which hold only a single value as an element.

-    Dictionaries are used to store data values in key:value pairs.

-    A dictionary is a collection which is unordered, changeable and do not allow duplicates.
 
-    Dictionaries are key & value pairs enclosed in { }

-    key & value are seperated by ':' while key and value pairs are sperated by ','

-    keys are mapped to their values

-    { } is an empty dictionary

-    dict is class of dictionary

-    Dictionary holds key:value pair.

# %%
![dictionaries-in-python.jpg](attachment:dictionaries-in-python.jpg)

# %%
x={1:[1,2,3],'rahela':(4,5,6)}  #'1' is int and 'rahela'is string,('f','g') is tuple        #dictionary, key:value
print(x,type(x))
# Out:
# {1: [1, 2, 3], 'rahela': (4, 5, 6)} <class 'dict'>

# %%
x ={1:[1,2,3],
    'hello':(4,5,6),
      ('f','g'):5}
x
# Out:
# {1: [1, 2, 3], 'hello': (4, 5, 6), ('f', 'g'): 5}

# %%
x ={1:[1,2,3],      ## key and value pair
    'hello':(4,5,6), ## key and value pair
      'hello': ['hi']} ## duplicates are not displayed but last value of the key is taken
x
# Out:
# {1: [1, 2, 3], 'hello': ['hi']}

# %% [markdown]
# ## Creating a Dictionary
#
# -     In Python, a dictionary can be created by placing a sequence of elements within curly {} braces, separated by ‘comma’. *       Dictionary holds pairs of values, one being the Key and the other corresponding pair element being its Key:value.
#
# -     Values in a dictionary can be of any data type and can be duplicated, whereas keys can’t be repeated and must be               immutable

# %%
x={1:[1,2,3],'rahela':(4,5,6)} 
print(x,type(x))
# Out:
# {1: [1, 2, 3], 'rahela': (4, 5, 6)} <class 'dict'>

# %% [markdown]
# ## creating an empty dictionary
#
# -    Empty dictionary can also be created by using dict().
#
# -    An empty dictionary can be created by just placing to curly braces{}.

# %%
x={} ## using {} 
print(x,type(x))
# Out:
# {} <class 'dict'>

# %%
x=dict() #using class dict()
print(x,type(x))
# Out:
# {} <class 'dict'>

# %% [markdown]
# ## Nested Dictionary
#
# -      Nesting Dictionary means putting a dictionary inside another dictionary.
#
# -      Nesting is of great use as the kind of information we can model in programs is expanded greatly.
#
# -      nested_dict = {'dict1': {'key_A': 'value_A'}, 'dict2': {'key_B': 'value_B'}}

# %% [markdown]
# ![nested-dictionary-in-python_thumbnail.webp](attachment:nested-dictionary-in-python_thumbnail.webp)

# %%
s={2:{1:'ziya'},3:{3:'Afsheen'}}
print(s)
# Out:
# {2: {1: 'ziya'}, 3: {3: 'Afsheen'}}

# %% [markdown]
# ## Length of dictionary
#
# -   len()is used to find the length of the dictionary

# %%
s={2:{1:'ziya'},3:{3:'Afsheen'}}
len(s)
# Out:
# 2

# %% [markdown]
# ## Range
#
# -    range()populates a numbers within a given range
#
# ### syntax for range() is
#
# -    range(start,end,step)
#
# -    start is starting number
#
# -    end is till end , not including end
#
# -    step is step size
#
# -    default values of start is zero and step is +1

# %%
r= range(1,11)  # till end means upto 10
print(r,type(r),hex(id(r)),sep='\n')
# Out:
# range(1, 11)
# <class 'range'>
# 0x2ca493d6490

# %%
x['hello'][0][-1]
# Out:
# 'i'

# %% [markdown]
# ## Methods

# %% [markdown]
# ![python-dictionary-methods-ipcisco.com_.jpg](attachment:python-dictionary-methods-ipcisco.com_.jpg)

# %%
dir(x)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# -   Dictionary is like a map that is used to store data in the form of a key: value pair.
#
# -   Python provides various built-in functions to deal with dictionaries
#
# 1.  clear()
#
#     Removes all items from the dictionary
#
# 2.  copy()
#
# -   Returns a shallow copy of the dictionary
#
# 3.  fromkeys()
#
# -   Creates a dictionary from the given sequence
#
# 4.  get()
#
# -   Returns the value for the given key
#
# 5.  items()
#
# -   Return the list with all dictionary keys with values
#
# 6.  keys()
#
# -   Returns a view object that displays a list of all the keys in the dictionary in order of insertion
#
# 7.  pop()
#
# -   Returns and removes the element with the given key
#
#
# 8.  popitem()
#
# -   Returns and removes the key-value pair from the dictionary
#
# 9. setdefault()
#
# -   Returns the value of a key if the key is in the dictionary else inserts the keywith a value to the dictionary
#
# 10. values()
#
# -   Updates the dictionary with the elements from another dictionary
#
# 11. update()
#
# -   Returns a list of all the values available in a given dictionary

# %%
# 30th_Oct_23

# %%
x = dict([(1,11), ## 1 is key and 11 is value of key 1 
         (2,22)])
x
# Out:
# {1: 11, 2: 22}

# %%
x = dict([(1,[11,111]), ## 1 is key and 11 and 111 is value of key 1 
         (2,22)])
x
# Out:
# {1: [11, 111], 2: 22}

# %%
x = {'k1' :1,
     'k2':2,
    'k3':3}
x
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
x['k3']
# Out:
# 3

# %% [markdown]
# ## .get()
#
# -       Returns the value of the specified key
#
# -       The get() method is a pre-built dictionary function that enables you to obtain the value linked to a particular key in
#         a dictionary.
#
# -       It is a secure method to access dictionary values without causing a KeyError if the key isn’t present.

# %% [markdown]
# ![python-get-dict.webp](attachment:python-get-dict.webp)

# %% [markdown]
# d = {'Name': 'ziya', 'Age': '3', 'Country': 'India'}
# print(d.get('Name'))
# print(d.get('Gender'))

# %%
x.get('k3')
# Out:
# 3

# %%
x['k']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x['k']
#
# KeyError: 'k'

# %%
x.get('k')

# %% [markdown]
# ## .update()
#
# -     Updates the dictionary with the specified key-value pairs.
#
# -    Python’s update() method is a built-in dictionary function that updates the key-value pairs of a dictionary using elements
#
# -    from another dictionary or an iterable of key-value pairs. With this method, you can include new data or merge it with          existing dictionary entries.

# %% [markdown]
# ![python-add-update-dict.png](attachment:python-add-update-dict.png)

# %%
x
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3}

# %%
x['k4'] = 4
x
# Out:
# {'k1': 1, 'k2': 2, 'k3': 3, 'k4': 4}

# %%
x['k1'] = 111 ### override k1 value from 1 to 111
x
# Out:
# {'k1': 111, 'k2': 2, 'k3': 3, 'k4': 4}

# %%
x.update([('k5', 5),   ## As we are updating both k5 and k6 values as tuples we are giving in a container ([()])
         ('k6', 6)])
x
# Out:
# {'k1': 111, 'k2': 2, 'k3': 3, 'k4': 4, 'k5': 5, 'k6': 6}

# %%
x.update({'k7':7, 'k8':8}) ## other way to update values
x
# Out:
# {'k1': 111, 'k2': 2, 'k3': 3, 'k4': 4, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 8}

# %%
a = {}
print(a,type(a), hex(id(a)), sep = '\n')

a.update(x)
print(a, type(a), hex(id(a)), sep = '\n')
# Out:
# {}
# <class 'dict'>
# 0x20475c9db00
# {'k1': 111, 'k2': 2, 'k3': 3, 'k4': 4, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 8}
# <class 'dict'>
# 0x20475c9db00

# %%
a
# Out:
# {'k1': 111, 'k2': 2, 'k3': 3, 'k4': 4, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 8}

# %%
d1 = {'Name': 'ziya', 'Age': '4', 'Country': 'India'}
d2 = {'Name': 'Afsheen', 'Age': '3'}
d1.update(d2)
print(d1)
# Out:
# {'Name': 'Afsheen', 'Age': '3', 'Country': 'India'}

# %% [markdown]
# ## .keys()
#
# -    Returns a list containing the dictionary's keys
#
# -    Extract only dictionary keys
#
# -    The keys() method in Python returns a view object with dictionary keys, allowing efficient access and iteration.

# %% [markdown]
# ![Python-keys.jpg](attachment:Python-keys.jpg)

# %% [markdown]
# d = {'Name': 'ziya', 'Age': '3', 'Country': 'India'}
# print(list(d.keys()))

# %%
a.keys() ## keys vl be written as dict_keys
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7', 'k8'])

# %%
aKeys = a.keys()
print(aKeys, type(aKeys), len(aKeys), sep = '\n')
print()
aKeys = list(aKeys)
print(aKeys, type(aKeys), len(aKeys), sep= '\n')
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7', 'k8'])
# <class 'dict_keys'>
# 8
#
# ['k1', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7', 'k8']
# <class 'list'>
# 8

# %% [markdown]
# ## .values()
#
# -    Returns a list of all the values in the dictionary
#
# -    The values() method in Python returns a view object containing all dictionary values, which can be accessed and iterated        through efficiently.

# %% [markdown]
# ![python-dict-keys-and-values.webp](attachment:python-dict-keys-and-values.webp)

# %%
d = {'Name': 'ziya', 'Age': '4', 'Country': 'India'}
print(list(d.values()))
# Out:
# ['ziya', '4', 'India']

# %%
aValues = a.values()
print(aValues, type(aValues), len(aValues), sep = '\n')
print()
aValues = list(aValues)
print(aValues, type(aValues), len(aValues), sep= '\n')
# Out:
# dict_values([111, 2, 3, 4, 5, 6, 7, 8])
# <class 'dict_values'>
# 8
#
# [111, 2, 3, 4, 5, 6, 7, 8]
# <class 'list'>
# 8

# %%
a.values()
# Out:
# dict_values([111, 2, 3, 4, 5, 6, 7, 8])

# %% [markdown]
# ## .items()
#
# -    Returns a list containing a tuple for each key value pair
#
# -    The items() method is a built-in dictionary function that retrieves a view object containing a list of tuples.
#
# -    Each tuple represents a key-value pair from the dictionary.
#
# -    This method is a convenient way to access both the keys and values of a dictionary simultaneously, and it is highly            efficient.

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
a.items() ## Acess both key and value
# Out:
# dict_items([('k1', 111), ('k2', 2), ('k3', 3), ('k4', 4), ('k5', 5), ('k6', 6), ('k7', 7), ('k8', 8)])

# %% [markdown]
# ## .pop()
#
# -    Removes the element with the specified key
#
# -    The pop() method is a pre-existing dictionary method that removes and retrieves the value linked with a given key from a        dictionary.
#
# -    If the key is not present in the dictionary, you can set an optional default value to be returned.
#
# -     pop takes  one value or argument  that argument is key it pops only value

# %% [markdown]
# ![Python-Dictionary-pop-.webp](attachment:Python-Dictionary-pop-.webp)

# %%
d = {'Name': 'ziya', 'Age': '4', 'Country': 'India'}
d.pop('Age')
print(d)
# Out:
# {'Name': 'ziya', 'Country': 'India'}

# %%
a.pop('k1')
# Out:
# 111

# %%
a
# Out:
# {'k2': 2, 'k3': 3, 'k4': 4, 'k5': 5, 'k6': 6, 'k7': 7, 'k8': 8}

# %% [markdown]
# a.pop()

# %% [markdown]
# ## .popitem()
#
# -   Removes the last inserted key-value pair
#
# -   The popitem() method removes the item that was last inserted into the dictionary.
#
# -   In versions before 3.7, the popitem() method removes a random item.
#
# -   The removed item is the return value of the popitem() method, as a tuple

# %% [markdown]
# ![Python-Dictionary-popitem-.webp](attachment:Python-Dictionary-popitem-.webp)

# %%
a.popitem() # pops both last key and value  pair
# Out:
# ('k8', 8)

# %%
car = {
  "brand": "Ford",
  "model": "ecosport",
  "year": 2010
}

car.popitem()

print(car)
# Out:
# {'brand': 'Ford', 'model': 'ecosport'}

# %% [markdown]
# ## .fromkeys()
#
# -    Returns a dictionary with the specified keys and value
#
# -    Python dictionary fromkeys() function returns the dictionary with key mapped and specific value.
#
# -    It creates a new dictionary from the given sequence with the specific value.

# %% [markdown]
# ![example-of-fromkeys-in-python.webp](attachment:example-of-fromkeys-in-python.webp)

# %%
a
# Out:
# {'k2': 2, 'k3': 3, 'k4': 4, 'k5': 5, 'k6': 6, 'k7': 7}

# %%
b = dict.fromkeys(a) ## writtens values as None
b
# Out:
# {'k2': None, 'k3': None, 'k4': None, 'k5': None, 'k6': None, 'k7': None}

# %%
c = {'g':'god',
     'h':'holla'}
z = c.fromkeys(a)
z
# Out:
# {'k2': None, 'k3': None, 'k4': None, 'k5': None, 'k6': None, 'k7': None}

# %%
zz = c.fromkeys() ## as value is not given displayed error
zz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 zz = c.fromkeys()
#       2 zz
#
# TypeError: fromkeys expected at least 1 argument, got 0

# %% [markdown]
# ## clear()
#
# -   The clear() method removes all the elements from a dictionary.

# %% [markdown]
# ![python-dict-clear.png.webp](attachment:python-dict-clear.png.webp)

# %%
d = {1: "ziya", 2: "Afsheen"}
d.clear()

# %%
d
# Out:
# {}

# %% [markdown]
# ## .copy()
#
# -      The copy() method returns a copy of the specified dictionary.
#
# -      copy() method returns a shallow copy of the dictionary.
#
# ### Syntax:
#
# -     dict.copy()
#
# ### Return:
#
# -    This method doesn’t modify the original, dictionary just returns copy of the dictionary.

# %% [markdown]
# ![copy-dictionary-and-edit-Python.webp](attachment:copy-dictionary-and-edit-Python.webp)

# %%
original = {1: 'hello', 2: 'world'}
 

new = original.copy() # copying using copy() function
 
# removing all elements from the list
# Only new list becomes empty as copy()
# does shallow copy.
new.clear()
 
print('new: ', new)
print('original: ', original)
# Out:
# new:  {}
# original:  {1: 'hello', 2: 'world'}

# %% [markdown]
# ## .setdefault()
#
# -    The setdefault() method returns the value of the item with the specified key.
#
# -    If the key does not exist, insert the key, with the specified value
#
# -    Python Dictionary setdefault() returns the value of a key (if the key is in dictionary).
#
# -    Else, it inserts a key with the default value to the dictionary.
#
# ## Syntax
#
#
# -     dictionary.setdefault(keyname, value)
#
# ### Parameter
#
#
# -     keyname----->The keyname of the item you want to return the value from (Required)
#
# -     value------->	If the key exist, this parameter has no effect. (optional)
#                     If the key does not exist, this value becomes the key's value
# ### Default
#
# -     None

# %% [markdown]
# ![python-setdefault-thumbnail.webp](attachment:python-setdefault-thumbnail.webp)

# %%
car = {
  "brand": "Ford",
  "model": "Ecosport",
  "year": 1964
}

x = car.setdefault("model", "Figo")

print(x)
# Out:
# Ecosport

# %%
## Python Dictionary setdefault()

# %%
d = {'a': 97, 'b': 98, 'c': 99, 'd': 100} # space key added using setdefault() method 
d.setdefault(' ', 32) 
print(d)
# Out:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, ' ': 32}

# %% [markdown]
# ## Using Python Dictionary setdefault() Method when key already existing in dictionary
#
# -    setdefault() method on any existing key of a dictionary, it’ll return the value of the existing key, but will not modify        the dictionary key.

# %%
d = {'a': 97, 'b': 98} 
print("setdefault() returned:", d.setdefault('b', 99)) 
print("After using setdefault():", d)
# Out:
# setdefault() returned: 98
# After using setdefault(): {'a': 97, 'b': 98}

# %% [markdown]
# ## Using Python Dictionary setdefault() Method when key not existing in dictionary
#
# -    If we use setdefault() method on any non-existing key of a dictionary, it’ll return the new value added and update the          dictionary with the key, value pair.

# %%
z = { 'A': 'Geeks', 'B': 'For'} 
print("Dictionary before using setdefault():", z) 
  
# using setdefault() when key is non-existing 
ret_value = z.setdefault('C', "Geeks") 
print("Return value of setdefault():", ret_value) 
  
print("Dictionary after using setdefault():", z)
# Out:
# Dictionary before using setdefault(): {'A': 'Geeks', 'B': 'For'}
# Return value of setdefault(): Geeks
# Dictionary after using setdefault(): {'A': 'Geeks', 'B': 'For', 'C': 'Geeks'}
