# %% [markdown]
# # Packages
#
# -  A python package is a collection of modules.
# -  Modules that are related to each other are mainly put in the same package.
# -  Python modules may contain several classes, functions, variables, etc. whereas Python packages contain several modules.
# -  Package in Python is a folder that contains various modules as files.
# -  A package is a container that contains various functions to perform specific tasks.

# %% [markdown]
# ![structure-of-packages.webp](attachment:structure-of-packages.webp)

# %%
-   A Python package usually consists of several modules.
-   A package is a folder containing modules and maybe other folders that themselves may contain more folders and modules.

# %% [markdown]
# ### Creating Package

# %% [markdown]
# -  create a package in Python named mypckg that will contain two modules module1 and modules2.
#
# -  To create this module follow the below steps:
#
#       -  Create a folder named mypckg.
#       - Inside this folder create an empty Python file i.e. __init__.py
#       - Then create two modules mod1 and mod2 in this folder.
#
#               -  mathmodule
#               - Phymodule

# %% [markdown]
# ### init.package
#
# -   init.py helps the Python interpreter recognize the folder as a package.
#
# -   It also specifies the resources to be imported from the modules.
#
# -   If the init.py is empty this means that all the functions of the modules will be imported.
#
# -   We can also specify the functions from each module to be made available.
#
# -   init.py
#
# -   This init.py will only allow the power and sum functions from the mod1 and mod2 modules to be imported.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ### Import Modules from a Package
#
# -   We can import these Python modules using the from…import statement and the dot(.) operator.
#
# ##### Syntax:
#
# -    import package_name.module_name
#
# -    We will import the modules from the above-created package and will use the functions inside those modules.

# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)

# %%
-  We can also import the specific function also using the same syntax.

       - from package261.mathsfunc import gfg
    
       - from package261.phyfunc import sum

# %% [markdown]
# ### Module:-
#
# -  A module as reusable, importable code,every package is a module — but not every module is a package.
#
# -   Python statements and definitions, like a file  can be considered as a module which can be imported with the help of import     statement.
#
# -   A package is a collection of modules in directories that give structure and hierarchy to the modules.
#
# -   In Python, Modules are simply files with the “. py” extension containing Python code that can be imported inside another         Python Program.
#
# -   A Python module is a file containing Python definitions and statements.
#
# -   A module can define functions, classes, and variables.

# %% [markdown]
# ![download%20%282%29.png](attachment:download%20%282%29.png)

# %% [markdown]
# ### Advantages of modules –
#
# -   Reusability: Working with modules makes the code reusability a reality.
#
# -   Simplicity: Module focuses on a small proportion of the problem, rather than focusing on the entire problem.
#
# -   Scoping: A separate namespace is defined by a module that helps to avoid collisions between identifiers.

# %% [markdown]
# ### Creating and Importing a module
#
# -   A module is simply a Python file with a .py extension that can be imported inside another Python program.
#
# -   The name of the Python file becomes the module name.
#
# -   The module contains definitions and implementation of classes, variables, and functions that can be used inside another         program.

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# ### Importing module from a package
#
# -   All the object from a module can be imported as a variable. This prevents the usage of the module name as a prefix.
#
#              from module_name_ import *

# %% [markdown]
# ![download%20%281%29.jpg](attachment:download%20%281%29.jpg)

# %%
Always ensure that the module file (e.g., calculator.py) and the file where you import and use the module (e.g., main.py) are in the same directory or in a location where Python can find the module (like in the Python path).
You can also organize your modules into packages (folders with an init.py file). This helps manage multiple related modules together.

# %% [markdown]
# ##### Understanding __init__.py
#
# - __init__.py helps the Python interpreter recognize the folder as a package.
#
# -  Any Python file, whose name is the module’s name with the .py extension, is a module.
#
# -  A directory must contain a file named __init__.py in order for Python to consider it as a package.
#
# -  The init file may be empty, or it may contain code to be executed upon package initialization.
#
# -  It also specifies the resources to be imported from the modules.
#
# -  If the __init__.py is empty this means that all the functions of the modules will be imported.
#
# -  We can also specify the functions from each module to be made available.
#
# -  init.py
#
# -  This init.py will only allow the power and sum functions from the mod1 and mod2 modules to be imported.

# %% [markdown]
# ##### we can also create the __init__.py file for the above module as:
#
#         __init__.py
#
#         from .mod1 import gfg
#         from .mod2 import sum
#    This __init__.py will only allow the gfg and sum functions from the mod1 and mod2 modules to be imported.

# %% [markdown]
# # Class in python
#
# -  class:-
#
#      -   Creating a class in Python involves defining a blueprint for creating objects.
#      -  A class is a user-defined blueprint or prototype from which objects are created.
#      - Classes provide a means of bundling data and functionality together.

# %% [markdown]
# ![understanding-class-python.png](attachment:understanding-class-python.png)

# %% [markdown]
# ## Aliasing
#
# -   An alias is essentially an alternate name for a module, function, or class.
#
# -   In Python, we can give another name of the function.
#
# -   For the existing function, we can give another name, which is nothing but function aliasing.
#
# -   Aliasing happens when the value of one variable is assigned to another variable because variables are just names that store     references to actual value.
#
# -   Creating an alias for a module in Python allows you to refer to the module with a different name within your code.
#
# -   This can be helpful if the original module name is lengthy or if you want to avoid naming conflicts.
#
# -   This technique can be particularly useful when dealing with modules with long names.
#
# -   when you need to differentiate between similar modules or prevent namespace clashes.

# %% [markdown]
# ![68747470733a2f2f6779616e6970616e6469742e636f6d2f70726f6772616d6d696e672f77702d636f6e74656e742f75706c6f6164732f323032322f31312f5448452d41532d4b4559574f52442d494e2d505954484f4e464f522d4352454154494e472d414c4941532d464.jpg](attachment:68747470733a2f2f6779616e6970616e6469742e636f6d2f70726f6772616d6d696e672f77702d636f6e74656e742f75706c6f6164732f323032322f31312f5448452d41532d4b4559574f52442d494e2d505954484f4e464f522d4352454154494e472d414c4941532d464.jpg)

# %% [markdown]
# ### Function aliasing in Python
#
# -  In aliasing, we create a new variable and assign the function reference to one existing function to the variable.
#
# -  This can be useful for several reasons, such as shortening long module names, avoiding naming conflicts, or enhancing code      readability.

# %%
first_variable = "PYTHON"
print("Value of first:", first_variable)
print("Reference of first:", id(first_variable))

print("--------------")

second_variable = first_variable # making an alias
print("Value of second:", second_variable)
print("Reference of second:", id(second_variable))

# %%
In the example above, first_variable is created first and then string ‘PYTHON’ is assigned to it. Statement first_variable = second_variable creates an alias of first_variable because first_variable = second_variable copies reference of first_variable to second_variable.

# %% [markdown]
# ##### To verify, let’s have look at the output of the above program:
#
# Value of first_variable: PYTHON
# Reference of first_variable: 2904215383152
# --------------
# Value of second_variable: PYTHON
# Reference of second_variable: 2904215383152

# %%
From the output of the above program, it is clear that first_variable and second_variable have the same reference id in memory.

So, both variables point to the same string object ‘PYTHON’.

# %%
, when the value of one variable is assigned to another variable, aliasing occurs in which reference is copied rather than copying the actual value.

# %% [markdown]
# ### Defining Maths Formulae Functions

# %% [markdown]
# ![download%20%283%29.png](attachment:download%20%283%29.png)

# %% [markdown]
# ### calling a function

# %% [markdown]
# ![download%20%284%29.png](attachment:download%20%284%29.png)

# %% [markdown]
# ### Defining Physics Formulae Functions

# %% [markdown]
# ![download%20%285%29.png](attachment:download%20%285%29.png)

# %% [markdown]
# ### calling Physics function

# %% [markdown]
# ![download%20%286%29.png](attachment:download%20%286%29.png)

# %% [markdown]
# ### Creating module: Mathmodule

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# ### Testing of  Math Module

# %% [markdown]
# ![download%20%281%29.jpg](attachment:download%20%281%29.jpg)

# %% [markdown]
# ### Creating Phymodule

# %% [markdown]
# ![download%20%282%29.jpg](attachment:download%20%282%29.jpg)

# %% [markdown]
# ### Testing phymodule

# %% [markdown]
# ![download%20%283%29.jpg](attachment:download%20%283%29.jpg)

# %% [markdown]
# ### Unit Testing for Mathmodule and Phymodule

# %% [markdown]
# #### Checking whether Mathmodule is running as a script or not

# %% [markdown]
# ![download%20%284%29.jpg](attachment:download%20%284%29.jpg)

# %% [markdown]
# ### Checking whether Phymodule running as a script or not

# %% [markdown]
# ![download%20%285%29.jpg](attachment:download%20%285%29.jpg)

# %% [markdown]
# ### Importing subpackages from modules

# %% [markdown]
# ##### Adding system path to packages we can import package folder

# %% [markdown]
# ![download%20%286%29.jpg](attachment:download%20%286%29.jpg)

# %% [markdown]
# ![download%20%287%29.jpg](attachment:download%20%287%29.jpg)
