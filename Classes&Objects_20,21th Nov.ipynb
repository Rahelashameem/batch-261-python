# %% [markdown]
# # Classes:
#
# -   In OOP(object oriented programming), every data value is an object of some class.
#
# -   A Class is like an object constructor, or a "blueprint" for creating objects.
#
# -   Class is considered as an blue-print or a template of an object.
#
# -   A class normally has methods(functions) and attributes(variables) within it.
#
# -   Normally,a class name starts Capital alphabet
#
# -   we create an object by process called as object instantiation
#
# -   All the classes user define,inherith(special methods)from a parent class called as object
#
# -   Creating a new class creates a new type of object, allowing new instances of that type to be made.
#
# -   Each class instance can have attributes attached to it for maintaining its state.
#
# -   Class instances can also have methods (defined by their class) for modifying their state.

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# ### creating a class:
#
# -    To create a class, use the keyword class

# %%
## Create a class named MyClass, with a property named x:

class MyClass:
  x = 5
print(MyClass)
# Out:
# <class '__main__.MyClass'>

# %%
class FooClass:  # userdefined class using class keyword
    pass

# %% [markdown]
# ### creating object  of Foo class

# %%
x = FooClass() # object instantiation

# %%
print(type(x))
# Out:
# <class '__main__.FooClass'>

# %% [markdown]
# ### Define Python Class

# %%
## We use the class keyword to create a class in Python. 

class ClassName:
    # class definition 
  #  we have created a class named ClassName.

class Bike:
    name = ""
    gear = 0 
    
 #   Bike - the name of the class
#    name/gear - variables inside the class with default values "" and 0 respectively

# %%
Note: The variables inside a class are called attributes.

# %%
dir(x)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# ### Object of Python Class:
#
# -   An object is called an instance of a class.
#
# -   A class is like a blueprint while an instance is a copy of the class with actual values.
#
# -   An object consists of:
#
#     -  State: It is represented by the attributes of an object. It also reflects the properties of an object.
#
#     -  Behavior: It is represented by the methods of an object. It also reflects the response of an object to other objects.
#
#     -  Identity: It gives a unique name to an object and enables one object to interact with other objects.

# %% [markdown]
# ![Blank-Diagram-Page-1-5.png](attachment:Blank-Diagram-Page-1-5.png)

# %% [markdown]
# ### Declaring Claas Objects (Also called instantiating a class)
#
# -    When an object of a class is created, the class is said to be instantiated.
#
# -    All the instances share the attributes and the behavior of the class.
#
# -    But the values of those attributes, i.e. the state are unique for each object.
#
# -    A single class may have any number of instances.

# %% [markdown]
# ## Example:
#
# ![Blank-Diagram-Page-1-3.png](attachment:Blank-Diagram-Page-1-3.png)

# %% [markdown]
# ### Example of Python Class and object
#
# -    Creating an object in Python involves instantiating a class to create a new instance of that class.
#
# -    This process is also referred to as object instantiation.

# %%
# Python3 program to
# demonstrate instantiating
# a class
class Dog:
 
    # A simple class
    # attribute
    attr1 = "mammal"
    attr2 = "dog"
 
    # A sample method
    def fun(self):
        print("I'm a", self.attr1)
        print("I'm a", self.attr2)
 
 
# Driver code
# Object instantiation
shitzu = Dog()
 
# Accessing class attributes
# and method through objects
print(shitzu.attr1)
shitzu.fun()
# Out:
# mammal
# I'm a mammal
# I'm a dog

# %% [markdown]
# ### creating a class student

# %%
class InnoStudent:
    pass

# %%
Naira = InnoStudent()

# %%
Naira.name, Naira.rollNo = 'Naira', 552

# %%
dir(Naira)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'name',
#  'rollNo']

# %% [markdown]
# ### Self Parameter:
#
# -    When we call a method of this object as myobject.method(arg1, arg2), this is automatically converted by Python into            MyClass.method(myobject, arg1, arg2) – this is all the special self is about.

# %%
class GFG:
    def __init__(self, name, company):
        self.name = name
        self.company = company
 
    def show(self):
        print("Hello my name is " + self.name+" and I" +
              " work in "+self.company+".")
 
 
obj = GFG("zoya", "Microsoft")
obj.show()
# Out:
# Hello my name is zoya and I work in Microsoft.

# %% [markdown]
# ### Python Constructors

# %%
## Earlier we assigned a default value to a class attribute,

class Bike:
    name = ""
...
# create object
bike1 = Bike()

## However, we can also initialize values using the constructors. For example,

class Bike:

    # constructor function    
    def __init__(self, name = ""):
        self.name = name

bike1 = Bike()

## Here, __init__() is the constructor function that is called whenever a new object of that class is instantiated.

### The constructor above initializes the value of the name attribute. 

### We have used the self.name to refer to the name attribute of the bike1 object.

If we use a constructor to initialize values inside a class, we need to pass the corresponding value during the object creation of the class.

bike1 = Bike("Mountain Bike")

Here, "Mountain Bike" is passed to the name parameter of __init__().

# %% [markdown]
# ### __init__() Function
#
# -    To understand the meaning of classes we have to understand the built-in __init__() function.
#
# -    All classes have a function called __init__(), which is always executed when the class is being initiated.
#
# -    Constructors are used to initializing the object’s state.
#
# -    A constructor also contains a collection of statements(i.e. instructions) that are executed at the time of Object              creation.
#
# -    It runs as soon as an object of a class is instantiated.
#
# -    The method is useful to do any initialization you want to do with your object.
#
# -    Note: The __init__() function is called automatically every time the class is being used to create a new object.

# %%
 ## Create a class named Person, use the __init__() function to assign values for name and age:
    
class Person:
        def __init__(self, name, age):
            self.name = name
            self.age = age

p1 = Person("esha", 5)

print(p1.name)
print(p1.age)
# Out:
# esha
# 5

# %% [markdown]
# ## creating a  class using methods

# %%
class InnoStudent:
    def details(self, name, rollNo, age, gender): ## for time being 1st positional parameter as self
        self.name = name
        self.age = age
        self.rno = rollNo
        self.gender = gender

# %%
zaira = InnoStudent()

# %%
zaira.details('zaira', 10, 5, 'Female')

# %%
zaira.name
# Out:
# 'zaira'

# %%
zaira.rno
# Out:
# 10

# %%
class InnoStudent:
    def __init__(self, fname, lname, gender, age): ## constructor(__init__)
        self.name = fname + ' '+ lname # fname-- first name; lname-- lastname
        self.gender = gender
        self.age = age
        self.email = fname+lname+str(age)+'@inno.com'

# %%
xyz = InnoStudent('zoya', 'Anam', 'Female', 6)

# %%
xyz.email
# Out:
# 'zoyaAnam6@inno.com'

# %% [markdown]
# # 21st Nov'23

# %%
class Student:
    def __init__(self, fname, lname, gender, dob): ## constructor(__init__)
        self.fname = fname 
        self.lname = lname
        self.name  = fname+' '+lname
        self.dob   = dob
        self.gender = gender
        self.email = fname+lname[:2]+dob[-2:]+'@stu.com'

# %%
stu1 = Student('ziya', 'afsheen', 'Female', '18-12-2018')

# %%
stu1.email
# Out:
# 'ziyaaf18@stu.com'

# %%
class Student:
    def __init__(self, fname, lname, gender, dob): ## constructor(__init__)
        self.fname = fname 
        self.lname = lname
        self.name  = fname+' '+lname
        self.dob   = dob
        self.gender = gender
        self.email = fname+lname[:2]+dob[-2:]+'@stu.com'
        self.fun   = self.xyz()
        
        def xyz(self):
            return 'hgfjyhfjk'

# %%
stu1 = student('ziya', 'afsheen', 'Female', '18-12-2018')

# %%
stu1.email
# Out:
# 'ziyaaf18@stu.com'

# %%
#### Using *args and **kwargs

# %%
class Student:
    def __init__(self, fname, lname, gender, dob, *marks): ## constructor(__init__)
        self.fname = fname 
        self.lname = lname
        self.name  = fname+' '+lname
        self.dob   = dob
        self.gender = gender
        self.email = fname+lname[:2]+dob[-2:]+'@stu.com'
        self.marks  = marks
        self.avg    = self.result()[0] # [0]--> index of first value
        self.res    = self.result()[1]  # [1] ---> index of second value
        
    def result(self):
            avg = (sum(self.marks)/len(self.marks))
            if min(self.marks)<40:
                return avg, 'Fail'
            elif avg < 60:
                return avg, 'SecondClass'
            elif avg < 80:
                return avg, 'FirstClass'
            else:
                return avg, 'FCWD' # FCWD-- first class with distinction

# %%
stu1 = Student('ziya', 'afsheen', 'Female', '18-12-2018', *[39, 90, 90, 90, 90])

# %%
stu1.avg, stu1.res
# Out:
# (79.8, 'Fail')

# %%
class Student:
    def init(self, fname, lname, dob , gender, passMark, *marks):
        self.name = fname
        self.name = lname
        self.name = fname + ' '+ lname
        self.dob = dob
        self.email = fname+lname[:2]+dob[-2:]+'@stu.com'
        self.marks = marks
        self.passmark = passMark
        self.avg = self.result()[0]
        self.res = self.result()[1]
    def result(self):
        avg = (sum(self.marks)/len(self.marks))
        if min(self.marks)<self.passmark:
            return avg, 'Fail'
        elif avg<60:
            return avg, 'Second class'
        elif avg<80:
            return avg, 'First class'
        else:
            return avg, 'FCWD'

# %%
stu1 = Student('Laxmi','Prasanna','Female','06-06-2001',40,*[35, 45, 60, 90, 90])

# %%
stu1.avg, stu1.res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 stu1.avg, stu1.res
#
# NameError: name 'stu1' is not defined

# %%
stu1.passmark = 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 stu1.passmark = 10
#
# NameError: name 'stu1' is not defined

# %%
stu1.passmark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 stu1.passmark
#
# NameError: name 'stu1' is not defined

# %%
stu1.result

# %%
class Stu:
    def __init__(self, *marks):
        self.marks = marks
        self.passmark = 40
    def res (self):
        return 'Fail' if min(self.marks) < self.passmark else 'Pass'

# %%
x = Stu(*[20,40,50])

# %%
x.res()
# Out:
# 'Fail'

# %%
x.passmark = 5

# %%
x.res()
# Out:
# 'Pass'

# %%
class FooClass:
    def __init__(self, *marks):
        self.passmark = 40
        self.marks = marks
    def result(self):
        return 'Fail' if min(self.marks) < self.passmark else 'Success'

# %%
x = FooClass(*[32, 50, 45])

# %%
x.result()
# Out:
# 'Fail'

# %%
x.passmark
# Out:
# 40

# %%
x.passmark = 1

# %%
x

# %%
x.result()
# Out:
# 'Success'

# %% [markdown]
# # Static attribute:
#
# -  Static variables are also referred to as variables defined inside the class but outside the methods.
#
# -  A static variable is a variable that remains common for the entire class, i.e. rather than creating a copy for each            instance, the same memory space is shared by all instances.
#
# -  It can be called directly from a class but not through the instances of a class.
#
# -  Since the static variables are limited to a class, they are also known as class variables.
#
# -  Neither an object can affect the class variable, nor the static variable can alter an object's condition.

# %% [markdown]
# ### Difference between an instance variable and a static variable:

# %% [markdown]
# ![mceu_9349379311662963103311.png](attachment:mceu_9349379311662963103311.png)

# %% [markdown]
# ### Features of a Static Variable in Python
#
#     -  A static variable is known as a class variable since it only belongs to the class in which it is defined.
#
#     -  All objects of the class share the same copy of the static variable.
#
#     -  Static variables are allocated memory once when the object for the class is created for the first time.
#
#     -  Static variables can be accessed through a class but not directly with an instance.
#
#     -  Static variables behavior doesn’t change for every object.
#
# ### Note:
#     -  All variables which are assigned a value in the class declaration are class variables. And variables that                      are assigned values inside methods are instance variables.

# %% [markdown]
# ### Access the static variable using the same class object
#
# -    We can directly access a static variable in Python using the same class object with a dot operator.
#
# -    'static' keyword to declare static variables. Python does not have a 'static' keyword to declare the static variable.
#
# -    In Python, we can simply declare a variable inside the class, note that it should not be inside any method, and that            variable will be known as a static or class variable.

# %%
class Bakery:
    type = 'cake'                  # Class Variable
    def __init__(self,flavor,price):
        self.flavor = flavor            # Instance Variable
        self.price = price            # Instance Variable
 
# Objects of Bakery class
a = Bakery('Butterscotch Cake', 300)
b = Bakery('Chocolate-Truffle Cake', 250)
 
print(a.type)  # prints "cake"
print(b.type)  # prints "cake"
print(a.flavor)    # prints "Butterscotch Cake"
print(b.flavor)    # prints "Chocolate-Truffle Cake"
print(a.price)    # prints "300"
print(b.price)    # prints "250"
# Out:
# cake
# cake
# Butterscotch Cake
# Chocolate-Truffle Cake
# 300
# 250

# %%
class FooClass:
    passmark = 40 # static attribute
    def __init__(self, *marks):
        self.marks = marks
    def result(self):
        return 'Fail' if min(self.marks) < self.passmark else 'Success'

# %%
x = FooClass(*[23,56])

# %%
x.result()
# Out:
# 'Fail'

# %%
x.passmark = 1

# %%
x.passmark

# %% [markdown]
# ### There are the two ways to define a static method in Python:
#
#       - Using the staticmethod() Method
#       - Using the @staticmethod Decorator

# %% [markdown]
# ### Using the staticmethod() Method
#
# -   A staticmethod() is a built-in function in Python that is used to return a given function as a static method.
#
# #### Syntax:
#
#     -  staticmethod (function)

# %% [markdown]
# -   A staticmethod() takes a single parameter.
# -  Where the passed parameter is a function that needs to be converted to a static method.

# %% [markdown]
# ##### create a function as a static method using staticmethod()

# %% [markdown]
# ### staticMethod.py

# %%
class Marks:  
    def Math_num(a, b): # define the static Math_num() function  
        return a + b  
  
    def Sci_num(a, b): # define the static Sci_num() function  
        return a +b  
  
    def Eng_num(a, b):  # define the static Eng_num() function  
        return a +b  
# create Math_num as static method  
Marks.Math_num = staticmethod(Marks.Math_num)  
  
# print the total marks in Maths  
print (" Total Marks in Maths" , Marks.Math_num(64, 28))   
  
# create Sci_num as static method  
Marks.Sci_num = staticmethod(Marks.Sci_num)  
  
# print the total marks in Science  
print (" Total Marks in Science" , Marks.Sci_num(70, 25))   
  
# create Eng_num as static method  
Marks.Eng_num = staticmethod(Marks.Eng_num)  
  
# print the total marks in English  
print (" Total Marks in English" , Marks.Eng_num(65, 30))
# Out:
#  Total Marks in Maths 92
#  Total Marks in Science 95
#  Total Marks in English 95

# %%
-  we declared the Math_num method, Sci_num method, and Eng_num method as static method outside the class using staticmethod() function. 
-  After that, we can call the static method directly using the class name Marks.
