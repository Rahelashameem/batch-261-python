# %% [markdown]
# ## maketrans()
#
# -    Python String maketrans() function is used to construct the transition table i.e specify the list of characters that need      to be replaced in the whole string or the characters that need to be deleted from the string.
#
# ### Syntax:
#
# -    maketrans(str1, str2, str3)
#
# ### Parameters:
#
# -    str1: Specifies the list of characters that need to be replaced.
# -    str2: Specifies the list of characters with which the characters need to be replaced.
# -    str3: Specifies the list of characters that need to be deleted.
#
# ### Returns:
#
# -   Returns the translation table which specifies the conversions that can be used by translate()

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %%
v = '*@!anything!@*'
v

# %%
d = v.maketrans({'@':'5',    ## prints ascii values of @=64,!=33,a=97
                '!':'7',
                'a' :'zz'})
d

# %%
v = '*@!anything!@*'
v
# Out:
# '*@!anything!@*'

# %%
v = '*@!anything!@*'
v

c=v.maketrans({'@':'z','n':'7','a':'ss'}) 
print(c)#64 ,115,95 is ascii default
# Out:
# {64: 'z', 110: '7', 97: 'ss'}

# %%
## translate()

-    translate() returns a string that is a modified string of givens string according to given translation mappings.

## translate() :

-    translate() is a built-in method in Python that is used to replace specific characters in a string with other characters or remove them altogether.

-    The translate() method requires a translation table that maps the characters to be replaced to their replacements.

-    This table translate() returns a string that is a modified string of givens string according to given translation mappings. 

-    * * This table can be generated using the maketrans() method, which takes two arguments: the characters to be replaced and their replacements.

### syntax: 

-    str.translate(translation_table)

# %% [markdown]
# ![maketrans-function-example.webp](attachment:maketrans-function-example.webp)

# %%
v = '*@!anything!@*'
d = v.maketrans({'@':'5',    ## prints ascii values of @=64,!=33,a=97
                '!':'7',
                'a' :'zz'})

v.translate(d)
# Out:
# '*57zznything75*'

# %%
 maketrans() by strings

# %%
j = "apple"
k = "mango"
l = "guava"
x='string'
print(x.maketrans(j,k,l))
# Out:
# {97: None, 112: 110, 108: 103, 101: 111, 103: None, 117: None, 118: None}

# %%
dict = {"j": "988", "b": "567", "c": "273"} ## dict
string = 'ziya'
print(string.maketrans(dict))
# Out:
# {106: '988', 98: '567', 99: '273'}

# %%
## conditional statements

# %%
if,elif,else stmts

# %%
ziyamarks = int(input('marks scored: '))

if ziyamarks >= 80:
    print('second round')
elif ziyamarks >= 70:
    print('first round')
elif ziyamarks >= 60:
    print('screening round')
else:
    print('study hard')
# Out:
# marks scored: 90
# second round

# %%
ziyamarks = int(input('marks scored: '))

if ziyamarks >= 60:
    print('screening round')
elif ziyamarks >= 70:
    print('first round')
elif ziyamarks >= 80:
    print('second round')
else:
    print('study hard')
# Out:
# marks scored: 60
# screening round

# %%
ziyamarks = int(input('marks scored: '))

if ziyamarks >= 70:
    print('first round')
elif ziyamarks >= 60:
    print('screening round')
elif ziyamarks >= 90:
    print('second round')
else:
    print('study hard')
# Out:
# marks scored: 76
# first round

# %%
ziyamarks = int(input('marks scored: '))

if ziyamarks >= 60:
    print('screening round')
elif ziyamarks >= 70:
    print('first round')
elif ziyamarks >= 80:
    print('second round')
else:
    print('study hard')
# Out:
# marks scored: 50
# study hard

# %%
## if,elif,else conditional stmts

# %%
marks=73
if marks<=60:
    print("study hard")
elif (marks<=70):
    print("screening round")
elif (marks<=80):
    print("first round")
else:
    print("second round")
# Out:
# first round

# %%
marks=62
if marks<=60:
    print("study hard")
elif (marks<=70):
    print("screening round")
elif (marks<=80):
    print("first round")
else:
    print("second round")
# Out:
# screening round

# %%
marks=45
if marks<=60:
    print("study hard")
elif (marks<=70):
    print("screening round")
elif (marks<=80):
    print("first round")
else:
    print("second round")
# Out:
# study hard
